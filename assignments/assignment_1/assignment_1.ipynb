# %%
# !git clone https://github.com/trvslhlt/ift_6135_representation_learning.git
# !cd ift_6135_representation_learning && git checkout assignment_1
# Out:
# Cloning into 'ift_6135_representation_learning'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 88 (delta 40), reused 58 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (88/88), 4.19 MiB | 11.54 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# Branch 'assignment_1' set up to track remote branch 'assignment_1' from 'origin'.
# Switched to a new branch 'assignment_1'

# %%
# !pip install uv
# !cd ift_6135_representation_learning && uv sync
# Out:
# Collecting uv
#   Downloading uv-0.10.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.10.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 25.2 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.10.4
# Using CPython 3.11.14
# Creating virtual environment at: .venv
# Resolved 152 packages in 0.74ms
# Prepared 149 packages in 1m 25s
# Installed 149 packages in 1.27s
#  + anyio==4.12.1
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + asttokens==3.0.1
#  + async-lru==2.1.0
#  + attrs==25.4.0
#  + babel==2.17.0
#  + beautifulsoup4==4.14.3
#  + bleach==6.3.0
#  + certifi==2026.1.4
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + comm==0.2.3
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + debugpy==1.8.19
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + executing==2.2.1
#  + fastjsonschema==2.21.2
#  + filelock==3.20.3
#  + fire==0.7.1
#  + fonttools==4.61.1
#  + fqdn==1.5.1
#  + fsspec==2026.1.0
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.11
#  + ift-6135-representation-learning==0.1.0 (from file:///content/ift_6135_representation_learning)
#  + imageio==2.37.2
#  + iniconfig==2.3.0
#  + ipykernel==7.1.0
#  + ipython==9.9.0
#  + ipython-pygments-lexers==1.1.1
#  + ipywidgets==8.1.8
#  + isoduration==20.11.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + json5==0.13.0
#  + jsonpointer==3.0.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + jupyter==1.1.1
#  + jupyter-client==8.8.0
#  + jupyter-console==6.6.3
#  + jupyter-core==5.9.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.3.0
#  + jupyter-server==2.17.0
#  + jupyter-server-terminals==0.5.4
#  + jupyterlab==4.5.2
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.28.0
#  + jupyterlab-widgets==3.0.16
#  + kiwisolver==1.4.9
#  + lark==1.3.1
#  + lazy-loader==0.4
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + matplotlib-inline==0.2.1
#  + medmnist==3.0.2
#  + mistune==3.2.0
#  + monai==1.5.2
#  + mpmath==1.3.0
#  + nbclient==0.10.4
#  + nbconvert==7.16.6
#  + nbformat==5.10.4
#  + nest-asyncio==1.6.0
#  + networkx==3.6.1
#  + notebook==7.5.2
#  + notebook-shim==0.2.4
#  + numpy==2.4.1
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvshmem-cu12==3.3.20
#  + nvidia-nvtx-cu12==12.8.90
#  + overrides==7.7.0
#  + packaging==25.0
#  + pandas==2.3.3
#  + pandocfilters==1.5.1
#  + parso==0.8.5
#  + pexpect==4.9.0
#  + pillow==12.1.0
#  + platformdirs==4.5.1
#  + pluggy==1.6.0
#  + prometheus-client==0.24.1
#  + prompt-toolkit==3.0.52
#  + psutil==7.2.1
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pycparser==2.23
#  + pygments==2.19.2
#  + pyparsing==3.3.1
#  + pytest==9.0.2
#  + python-dateutil==2.9.0.post0
#  + python-json-logger==4.0.0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + pyzmq==27.1.0
#  + referencing==0.37.0
#  + requests==2.32.5
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rpds-py==0.30.0
#  + scikit-image==0.26.0
#  + scikit-learn==1.8.0
#  + scipy==1.17.0
#  + seaborn==0.13.2
#  + send2trash==2.1.0
#  + setuptools==80.9.0
#  + six==1.17.0
#  + soupsieve==2.8.2
#  + stack-data==0.6.3
#  + sympy==1.14.0
#  + termcolor==3.3.0
#  + terminado==0.18.1
#  + threadpoolctl==3.6.0
#  + tifffile==2026.2.16
#  + tinycss2==1.4.0
#  + torch==2.9.1
#  + torchvision==0.24.1
#  + tornado==6.5.4
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + triton==3.5.1
#  + typing-extensions==4.15.0
#  + tzdata==2025.3
#  + uri-template==1.3.0
#  + urllib3==2.6.3
#  + wcwidth==0.2.14
#  + webcolors==25.10.0
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
#  + widgetsnbextension==4.0.15

# %% [markdown]
# Next, navigate to your project's root directory (`ift_6135_representation_learning`) where `pyproject.toml` is located, and then install the dependencies using `uv`:

# %%
# !cd ift_6135_representation_learning/assignments/assignment_1 && \
  uv run python main_classification.py \
    --model mlp \
    --logdir /content/ift_6135_representation_learning/assignments/assignment_1/logs
# Out:
# Using device: cuda
# 100% 206M/206M [00:18<00:00, 10.9MB/s]
# Build model MLP...
# Initialized MLP model with 2971849 total parameters, of which 2971849 are learnable.
# Model architecture:
#  MLP(
#   (hidden_layers): ModuleList(
#     (0-3): 4 x Linear()
#   )
#   (output_layer): Linear()
# )
#
#
# /content/ift_6135_representation_learning/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#
# [TRAIN] Epoch: 14, Iter: 400, Loss: 0.00539
# [TRAIN] Epoch: 14, Iter: 480, Loss: 0.00624
# [TRAIN] Epoch: 14, Iter: 560, Loss: 0.00575
# [TRAIN] Epoch: 14, Iter: 640, Loss: 0.00526
# == [TRAIN] Epoch: 14, Accuracy: 0.702 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: 0.00770
# === [VAL] Epoch: 14, Iter: 78, Accuracy: 0.695 ===>
# 100% 15/15 [09:56<00:00, 39.77s/it]
# [TEST] Epoch: 14, Iter: 0, Loss: 0.00743
# === [TEST] Epoch: 14, Iter: 56, Accuracy: 0.678 ===>
# ===== Best validation Accuracy: 0.695 =====>
# Writing training logs to /content/ift_6135_representation_learning/assignments/assignment_1/logs...

# %% [markdown]
# After installation, you can navigate back to the root `/content` directory if needed:

# %%
# %ls /content/ift_6135_representation_learning/assignments/assignment_1/logs
# %cat /content/ift_6135_representation_learning/assignments/assignment_1/logs/results.json
# Out:
# results.json
# {
#     "train_losses": [
#         0.010852405870304171,
#         0.009149108451670553,
#         0.008642860746559603,
#         0.008250157002380831,
#         0.007806505548872399,
#         0.007265436767758123,
#         0.00691830303723981,
#         0.00669298968496461,
#         0.006566485831882293,
#         0.0064190787065821885,
#         0.006319071471579848,
#         0.006229978431000307,
#         0.006225263276620952,
#         0.006119260454489445,
#         0.006028634399324022
#     ],
#     "valid_losses": [
#         0.009425552443990222,
#         0.008907837245047468,
#         0.008808987928389371,
#         0.008285229713243398,
#         0.007595778572597081,
#         0.007373305161401065,
#         0.007215246852911725,
#         0.00692647154431177,
#         0.006621847783887313,
#         0.006384863164511663,
#         0.006376885602698675,
#         0.006224371056673646,
#         0.006266265347175582,
#         0.006158115931704072,
#         0.0061106822524172625
#     ],
#     "train_accs": [
#         0.4729396337126596,
#         0.5583548186344235,
#         0.5829369665718347,
#         0.6001066856330017,
#         0.6213660206258894,
#         0.6446812766714088,
#         0.6604396337126598,
#         0.6689522581792328,
#         0.6754756401137989,
#         0.682688033428164,
#         0.6873666429587484,
#         0.6899448790896153,
#         0.6939344772403984,
#         0.6971128200568995,
#         0.7020692567567564
#     ],
#     "valid_accs": [
#         0.5550830696202532,
#         0.5762064875681191,
#         0.5673655067818074,
#         0.5955300632911392,
#         0.6411787973174566,
#         0.6306368670886074,
#         0.6514833863777446,
#         0.6655261078967323,
#         0.6680775314946716,
#         0.689636075798469,
#         0.6891020574147187,
#         0.6925632915919337,
#         0.6907041140749485,
#         0.6954311713387692,
#         0.6954905066309094
#     ],
#     "test_loss": 0.008402536402603513,
#     "test_acc": 0.6780884506409628
# }

# %%
# Example: Importing a Python file from the cloned repository
# Assuming you have a file named 'my_module.py' in the root of your cloned 'your_repo_name' directory
import sys
sys.path.append('ift_6135_representation_learning/assignments/assignment_1/')

# Example: Reading a CSV file from the cloned repository
# import pandas as pd
# df = pd.read_csv('your_repo_name/data.csv')
# display(df.head())
